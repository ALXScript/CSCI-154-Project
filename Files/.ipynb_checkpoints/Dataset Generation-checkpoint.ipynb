# %%
import crater_math as cm
import our_tools
import pandas as pd

df = pd.read_csv("Datasets/meteorite_data.csv")
ice = df
ice['KE'] = cm.solveKinEnergy(df['mass'], 20)
ice['diameter'] = cm.solveDiameter(1,1,1,ice['KE'], cm.dicProjectileDensity["ice"], cm.dicTargetDensity["sedimentary"])
ice
# Out:
#                       name       mass               GeoLocation         KE  \
# 0                   Aachen       21.0     (50.775000, 6.083330)       4.20
# 1                   Aarhus      720.0    (56.183330, 10.233330)     144.00
# 2                     Abee   107000.0  (54.216670, -113.000000)   21400.00
# 3                 Acapulco     1914.0   (16.883330, -99.900000)     382.80
# 4                  Achiras      780.0  (-33.166670, -64.950000)     156.00
# 5                 Adhi Kot     4239.0    (32.100000, 71.800000)     847.80
# 6      Adzhi-Bogdo (stone)      910.0    (44.833330, 95.166670)     182.00
# 7                     Agen    30000.0     (44.216670, 0.616670)    6000.00
# 8                   Aguada     1620.0  (-31.600000, -65.233330)     324.00
# 9            Aguila Blanca     1440.0  (-30.866670, -64.550000)     288.00
# 10        Aioun el Atrouss     1000.0    (16.398060, -9.570280)     200.00
# ...
